# %% [markdown]
# # Interactive Data Visualization for Global Health
#
# ## Lecture 2: Hello, World of Statistical Graphics

# %% [markdown]
# ## Outline:
# * a taxonomy of data,
# * Tufte's concept of the master graphic,
# * exercise one,
# * related technologies,
# * "hello, world",
# * "hello, world" for statistical graphics,
# * exercise two.

# %% [markdown]
# ## Questions?

# %% [markdown]
# ## Homework

# %% [markdown]
# ## Reading

# %%
Image('images/van_vijk_simple_model.png', embed=True)

# %% [markdown]
# ## $$I(t)=V(D;S;t)$$
#
# ## Data $D$ is transformed according to a specification $S$ into a time varying image $I(t)$.

# %% [markdown]
# ## The image $I$ is perceived by a user, with an increase in knowledge $K$ as a result:
#
# ## $$\frac{dK}{dt} = P(I;K).$$
#
# ## ($P$ = Cognition; $E$ = Exploration).

# %% [markdown]
# ## In other words, a great visualization method is used by many people, who use it routinely to obtain highly valuable knowledge, without having to spend time and money on hardware, software, and effort. Indeed, quite obvious.

# %% [markdown]
# ## Taxonomy of data
# * Nominal
# * Ordinal
# * Interval
# * Ratio

# %% [markdown]
# Taxonomy of data, history of big data (refs: S. S. Stevens, On the Theory of Scales of Measurement, http://www.jstor.org/stable/1671815; Unwin,”Introduction” in Graphics of Large Data Sets: Visualizing a million from Unwin, et al.) (10 min)

# %% [markdown]
# ## Nominal

# %% [markdown]
# ## Ordinal

# %% [markdown]
# ## Interval

# %% [markdown]
# ## Ratio

# %% [markdown]
# ## Meaningful quantitative information always involves relationships

# %% [markdown]
# ## [Tufte's concept of the "Master Graphic"](https://www.google.com/search?q=tufte+Master+Graphic&tbm=isch)

# %%
Image(url="http://3.bp.blogspot.com/_AYITBbUkIRQ/S_r2t_276AI/AAAAAAAAALc/GbQfEXOEZ6I/s1600/Minard.png", embed=True)

# %% [markdown]
# ## Graph Design Test: http://www.perceptualedge.com/files/GraphDesignIQ.html

# %% [markdown]
# ## Some other interesting things to search for:
#
# * Pre-Playfair: sun spots, early tables, euclid’s elements, etc.
# * William Playfair’s work
# * Yule, Karsten, ISOTYPE
# * Tukey, Cleveland, and Bell Labs
# * Bertin, Tufte, and the rise of theory
# * Infoviz in TIME, USA Today, etc.
# * Leland Wilkinson, Hadley Wickham, Grammar of graphics
# * Ben Fry, Jeff Heer, Mike Bostock, and the recent computer science innovations like data-driven documents

# %% [markdown]
# ## Survey of some related art/technologies:

# %% [markdown]
# ##	Info viz
# * Tufte declares war on Time mag infographics, Cairo investigates seriously.

# %%
# %cd /home/j/Project/Models/IDV4GH/lectures/
from IPython.display import Image
# Out:
# /snfs1/Project/Models/IDV4GH/lectures

# %%
Image("images/holmes_diamonds.png", embed=True)

# %% [markdown]
# ## Motion graphics
# * Moving beautiful infographics.
#
# <iframe width="420" height="315" src="//www.youtube.com/embed/MbWDNM0wuAc" frameborder="0" allowfullscreen></iframe>

# %% [markdown]
# ## Comics
# * [Scott McCloud](https://www.google.com/search?q=scott+mccloud+understanding+comics&)’s theory on representation vs abstraction from Understanding Comics

# %% [markdown]
# ## Animation
# * Drawing on representational style of comics, but using persistence of vision and change over time to make drawing appear to move.  Also 3D graphics.

# %% [markdown]
# ## Video games
# * As an extension of comics and animation, but including interactivity. The evolution over time, from very crude (pong), through more realistic (I was blown away by Wolfenstein 3D), to today’s games with breathtaking beauty.

# %%
Image(url="http://spectrum.ieee.org/img/pong_cabbig-web-1360088324690.jpg", embed=True)

# %% [markdown]
# ## User interface (UI) design
# * In parallel to video game development, but with a different utility and hence different focus.
#
# ## See also, User *experience* (UX) design

# %% [markdown]
# ## Web design
# * A merging of user interface design and graphic design, that has become so widespread it is worthy of separate consideration.

# %% [markdown]
# ## Sketching exercise

# %%
Image(filename="/home/j/Project/Models/IDV4GH/lectures/images/stravinsky1.png", embed=True)

# %%
Image(filename="/home/j/Project/Models/IDV4GH/lectures/images/stravinsky2.png", embed=True)

# %% [markdown]
# ## The history of “hello, world”.

# %% [markdown]
# ## A diversion related to javascript and d3: [Open source](https://github.com/mbostock/d3)
# * culture,
# * revision control,
# * contributing code/docs/fixes (and Wikipedia)

# %% [markdown]
# ## Exercise:
# * replicate "hello, world" of statistical graphics in D3

# %% [markdown]
# ## Extensions to exercise:
# * change the formatting of the labels on the axes
# * extend to include first 10 digits of pi, and first 100 digits, and add a button to choose which
#
# ## Extra:
# * add a button to choose any number of digits to display

# %% [markdown]
# ## Homework:
# * Sketch the “master graphic” for your visualization project.  We will have much more to say about interaction as the class develops, but for now we need to get some ideas flowing about how to show an overview. Try to produce 10 different ways to represent the data (quick sketches), and then pick the one you think is most promising, and sketch 10 variants of how to do it.

# %%
# !cp /homes/abie/notebook/2013_06_26b_IDV4GH_L2.ipynb /homes/abie/nbconvert/L2.ipynb
# !cd /homes/abie/nbconvert/; ./nbconvert.py --format reveal L2.ipynb
# !cp /homes/abie/nbconvert/L2* /home/j/Project/Models/IDV4GH/lectures/
# Out:
# ...
# Warning, we are deprecating this version of nbconvert,
# please consider using the new version.
# ...

# %%
import ipynb_style
ipynb_style.presentation()
# Out:
# <style type="text/css">
# div.input {
# width: 1024px; /* about 80 chars + buffer */
# }
#
# div.text_cell {
# width: 1024px /* instead of 100%, */
# }
#
# div.text_cell_render {
# /*font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;*/
# font-family: "Charis SIL", serif; /* Make non-code text serif. */
# line-height: 145%; /* added for some line spacing of text. */
# font-size: 28pt;
# }
#
# /* Set the size of the headers */
# div.text_cell_render h1 {
# font-size: 36pt;
# }
#
# div.text_cell_render h2 {
# font-size: 32pt;
# }
#
# div.text_cell_render li {
# line-height: 1.2em;
# }
#
# div.text_cell_render p {
# font-size: 14pt;
# line-height: 1em;
# }
#
# .CodeMirror {
# font-size: 14pt;
#  font-family: Consolas, monospace;
#  }
#
# .rendered_html ol {list-style:decimal; margin: 1em 2em;}
#
# </style>

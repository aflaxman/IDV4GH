# %% [markdown]
# # Interactive Data Visualization for Global Health
#
# ## Lecture 6: (Geographic) Maps

# %% [markdown]
# ## Geographic maps provide a very engaging visual element, and can contextualize our work in *global* health.

# %% [markdown]
# ## Comparisons *between* geographically close areas can provide insight as well as motivation.

# %% [markdown]
# Borrowing strength from geographically near areas is also a method we often use to fill in the gaps in our sparse and noisy data.  But that is a story for another time.

# %% [markdown]
# ## *Today*, we will have a look at how to include maps in IDVs with D3js.
# ## *And*, we will continue our example-based d3 drills, and try to push forwards our projects.

# %% [markdown]
# ## Outline:
# * results of peer critiques,
# * javascript quiz/exercise,
# * geographic maps and data,
# * getting data in to Javascript,
# * geographic maps in d3,
# * project work time.

# %% [markdown]
# ## Results of peer critiques.

# %% [markdown]
# ## Javascript quiz/exercise.

# %% [markdown]
# ##Geographic map projections:
# * how do you show something round on something flat?
# * [XKCD's take](http://xkcd.com/977/).

# %% [markdown]
# ## Excellent examples:
# * Google maps [mercator puzzle](http://gmaps-samples.googlecode.com/svn/trunk/poly/puzzledrag.html),
# * [GeoGuesser](http://geoguessr.com/).

# %% [markdown]
# ## How to display data on maps?

# %%
from IPython.display import Image

# %%
cd /home/j/Project/Models/IDV4GH/lectures/images
# Out:
# /snfs1/Project/Models/IDV4GH/lectures/images

# %% [markdown]
# ## Not necessarily how you display it without a map

# %%
Image('few_maps_1.png', embed=True)

# %% [markdown]
# ## Choropleth map: data represented by variation in color

# %%
Image("few_maps_2.png", embed=True)

# %% [markdown]
# ## Data represented by markers of varying area, positioned meaningfully

# %%
Image("few_maps_3.png", embed=True)

# %% [markdown]
# ## Cartogram: Data represented by varying area and color

# %%
Image(url="http://upload.wikimedia.org/wikipedia/commons/4/47/Cartlinearlarge.png", embed=True)

# %% [markdown]
# ## Micromaps: a cool combination of geographic maps and other data representations

# %%
Image(filename="micromap_design.png", embed=True)

# %% [markdown]
# ## Getting data in to Javascript

# %% [markdown]
# ## Geographic maps in d3

# %% [markdown]
# ## Project work time

# %% [markdown]
# ## Reading
#
# * S. Murray, *IDV4W*, Ch [10](http://chimera.labs.oreilly.com/books/1230000000345/ch10.html);
# * S. Few, [Introduction to Geographical Data Visualization](http://www.perceptualedge.com/articles/visual_business_intelligence/geographical_data_visualization.pdf), Visual Business Intelligence Newsletter, March/April 2009.

# %% [markdown]
# ## Homework: update your draft of your project, identify the technical challenge you need to solve.
# ##If there is none, *add a geomap*.

# %%
# !cp /homes/abie/notebook/2013_07_15_IDV4GH_L6.ipynb /homes/abie/nbconvert/L6.ipynb
# !cd /homes/abie/nbconvert/; ./nbconvert.py --format reveal L6.ipynb
# !cp /homes/abie/nbconvert/L6* /home/j/Project/Models/IDV4GH/lectures/
# Out:
# ...
# Warning, we are deprecating this version of nbconvert,
# please consider using the new version.
# ...

# %%
import ipynb_style
ipynb_style.presentation()
# Out:
# <style type="text/css">
# div.input {
# width: 1024px; /* about 80 chars + buffer */
# }
#
# div.text_cell {
# width: 1024px /* instead of 100%, */
# }
#
# div.text_cell_render {
# /*font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;*/
# font-family: "Charis SIL", serif; /* Make non-code text serif. */
# line-height: 145%; /* added for some line spacing of text. */
# font-size: 28pt;
# }
#
# /* Set the size of the headers */
# div.text_cell_render h1 {
# font-size: 36pt;
# }
#
# div.text_cell_render h2 {
# font-size: 32pt;
# }
#
# div.text_cell_render li {
# line-height: 1.2em;
# }
#
# div.text_cell_render p {
# font-size: 14pt;
# line-height: 1em;
# }
#
# .CodeMirror {
# font-size: 14pt;
#  font-family: Consolas, monospace;
#  }
#
# .rendered_html ol {list-style:decimal; margin: 1em 2em;}
#
# </style>

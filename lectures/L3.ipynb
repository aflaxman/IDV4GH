# %% [markdown]
# # Interactive Data Visualization for Global Health
#
# ## Lecture 3: The oft conflicting principles of good graphs

# %% [markdown]
# ## Outline:
#
# * a range of approaches,
# * often conflicting principles,
# * exercise one,
# * theory of visual cognition,
# * $\mathbb{FONTS}$,
# * exercise two

# %% [markdown]
# ## Questions?

# %% [markdown]
# ## Tour a solution to yesterday's exercise (?)

# %% [markdown]
# ## Quiz Question: What does this code do?
#     d3.select("body").selectAll("p")
#         .data([1,2,3,4,5])
#         .enter()
#         .append("p")
#         .text("New paragraph!");

# %% [markdown]
# ## Last Homework
# * $10 + 10$ sketches

# %% [markdown]
# ## Last Reading:
# * S. Murray, *Interactive Data Visualization for the Web*, Chapter 5;
# * S. Few, Data Visualization for Human Perception.

# %% [markdown]
# ## A range of approaches to a theory of visualization

# %% [markdown]
# ## Aesthetic approach

# %% [markdown]
# (10 min)
# Meanwhile, practitioners from Tufte to S Few to Alberto Cairo have developed beautiful examples of what works and collected their experiences on what doesn’t, drawing to greater and lesser degree on deductive and inductive methods.

# %%
Image("images/tufte_data_ink_ratio_1.png", embed=True)

# %%
Image("images/tufte_data_ink_ratio_2.png", embed=True)

# %% [markdown]
# [A nice discussion of this here](http://www.perceptualedge.com/articles/visual_business_intelligence/sometimes_we_must_raise_our_voices.pdf).

# %% [markdown]
# ## Experimental approach

# %% [markdown]
#  (10 min)
#     The statisticians and computer scientists in the golden era of Bell Labs took a more inductive approach, using human factors research and experimental psychology methods to identify principles of good graphs.  This has been developed in parallel and carried on by psychologists S Pinker and Kosslyn, as well as Colin Ware who have done an impressive job connecting the theories and experimental findings of visual perception and cognition to the practice of visual communication.

# %%
# %cd /home/j/Project/Models/IDV4GH/lectures
from IPython.display import Image
# Out:
# /snfs1/Project/Models/IDV4GH/lectures

# %%
Image("images/cleveland_mcgill_elementary_perceptual_tasks.png", embed=True)

# %%
Image("images/cleveland_mcgill_error_in_perceptual_tasks.png", embed=True)

# %%
Image("images/cleveland_mcgill_stacked_bar.png", embed=True)

# %%
Image("images/cleveland_mcgill_grouped_dot.png", embed=True)

# %% [markdown]
# ## Linguistic approach

# %% [markdown]
#  (10 min)
# Recall a tendency from last lecture’s history: the dream of developing a grammar of graphics (book by Wickham, popular R package ggplot). Called out by name in the first known book on making plots.  There the dream is to have a complete description of everything that makes sense as a graphic.  But even grammar guides for speech have some short-comings.
# Influential work from a related intellectual tradition is the semiotics of graphics by Bertin, introduced by  funny image: Brandon Bird, Signifier and Signified, http://www.brandonbird.com/signifier_signified.html

# %%
Image(url="http://scienceoss.com/wp-content/uploads/2008/03/hist-sorted.png", embed=True)

# %% [markdown]
# ## Principles in summary

# %% [markdown]
# ## This yields a diverse assortment of principles of good graphics.  The often conflicting principles of good graphics for your future investigation from:
# * E. Tufte, *Visual display of quantitative information*;
# * W. Cleveland, *The elements of graphing data*;
# * S. Kosslyn, *Graphic design for mind and eye*.
# ## All these approaches have something to offer.  But don’t take any of them too seriously.

# %% [markdown]
# ## [Summary in two pages by Stephen Few](http://www.perceptualedge.com/images/Effective_Chart_Design.pdf)

# %% [markdown]
# ## Drawing Exercise: drawing different types of charts, quickly

# %% [markdown]
#  (modeled on the cartooning book exercise) (5 min)

# %% [markdown]
# ## Theory of visual cognition
# * [Gestalt Principles](http://facweb.cs.depaul.edu/sgrais/gestalt_principles.htm) (e.g. Proximity, Similarity, Enclosure, Continuity)
# * [Preattentive visual processing](http://www.csc.ncsu.edu/faculty/healey/PP/)

# %% [markdown]
#  (folk theorem, experimental psych) as illustrated by Few, and including the gestalt principles (20 min)

# %% [markdown]
# ## Question time on WWW, HTML, CSS, Javascript, SVG

# %% [markdown]
#  (interactive data visualization book) (30 min)

# %% [markdown]
# ## Fonts

# %% [markdown]
# advice from A. Cairo
#
# two web resources from UWisc Design Lab

# %% [markdown]
# <iframe src="http://player.vimeo.com/video/65353988" width="500" height="281" frameborder="0" webkitAllowFullScreen mozallowfullscreen allowFullScreen></iframe> <p><a href="http://vimeo.com/65353988">The History of Typography - Animated Short</a> from <a href="http://vimeo.com/forrestmedia">Ben Barrett-Forrest</a> on <a href="https://vimeo.com">Vimeo</a>.</p>

# %% [markdown]
# ## Resources:
# * [http://wordmark.it/](http://wordmark.it/)
# * [http://www.typeconnection.com/](http://www.typeconnection.com/)

# %% [markdown]
# ## Homework: prepare data for your project prototype
# * A short discussion of data for D3js

# %% [markdown]
# ## Reading:
# * S. Kosslyn and C. Charbris, [The mind is not a camera, the brain is not a VCR](http://www.wjh.harvard.edu/~kwn/Kosslyn_pdfs/1993Kosslyn_AldusMag4_SeptOct_MindNotCamera.pdf). Aldus Magazine, Sept/Oct 1993;
# * S. Murray, *Interactive Data Visualization for the Web*, Chapter 6.

# %%
# !cp /homes/abie/notebook/2013_06_27_IDV4GH_L3.ipynb /homes/abie/nbconvert/L3.ipynb
# !cd /homes/abie/nbconvert/; ./nbconvert.py --format reveal L3.ipynb
# !cp /homes/abie/nbconvert/L3* /home/j/Project/Models/IDV4GH/lectures/
# Out:
# ...
# Warning, we are deprecating this version of nbconvert,
# please consider using the new version.
# ...

# %%
import ipynb_style
ipynb_style.presentation()
# Out:
# <style type="text/css">
# div.input {
# width: 1024px; /* about 80 chars + buffer */
# }
#
# div.text_cell {
# width: 1024px /* instead of 100%, */
# }
#
# div.text_cell_render {
# /*font-family: "Helvetica Neue", Arial, Helvetica, Geneva, sans-serif;*/
# font-family: "Charis SIL", serif; /* Make non-code text serif. */
# line-height: 145%; /* added for some line spacing of text. */
# font-size: 28pt;
# }
#
# /* Set the size of the headers */
# div.text_cell_render h1 {
# font-size: 36pt;
# }
#
# div.text_cell_render h2 {
# font-size: 32pt;
# }
#
# div.text_cell_render li {
# line-height: 1.2em;
# }
#
# div.text_cell_render p {
# font-size: 14pt;
# line-height: 1em;
# }
#
# .CodeMirror {
# font-size: 14pt;
#  font-family: Consolas, monospace;
#  }
#
# .rendered_html ol {list-style:decimal; margin: 1em 2em;}
#
# </style>
